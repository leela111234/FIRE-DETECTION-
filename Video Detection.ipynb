# %%
"""
Course:  Training YOLO v3 for Objects Detection with Custom Data

Section-2
Objects Detection on Video with YOLO v3 and OpenCV
File: yolo-3-video.py
"""


# Detecting Objects on Video with OpenCV deep learning library
#
# Algorithm:
# Reading input video --> Loading YOLO v3 Network -->
# --> Reading frames in the loop --> Getting blob from the frame -->
# --> Implementing Forward Pass --> Getting Bounding Boxes -->
# --> Non-maximum Suppression --> Drawing Bounding Boxes with Labels -->
# --> Writing processed frames
#
# Result:
# New video file with Detected Objects, Bounding Boxes and Labels


# Importing needed libraries
import numpy as np
import cv2
import time


"""
Start of:
Reading input video
"""

# Defining 'VideoCapture' object
# and reading video from a file
# Pay attention! If you're using Windows, the path might looks like:
# r'videos\traffic-cars.mp4'
# or:
# 'videos\\traffic-cars.mp4'
video = cv2.VideoCapture('videos/fire4.mp4')

# Preparing variable for writer
# that we will use to write processed frames
writer = None

# Preparing variables for spatial dimensions of the frames
h, w = None, None

"""
End of:
Reading input video
"""


"""
Start of:
Loading YOLO v3 network
"""

# Loading COCO class labels from file
# Opening file
# Pay attention! If you're using Windows, yours path might looks like:
# r'yolo-coco-data\coco.names'
# or:
# 'yolo-coco-data\\coco.names'
# with open('yolo-coco-data/coco.names') as f:
#     # Getting labels reading every line
#     # and putting them into the list
#     labels = [line.strip() for line in f]
labels = ['fire']


# # Check point
# print('List with labels names:')
# print(labels)

# Loading trained YOLO v3 Objects Detector
# with the help of 'dnn' library from OpenCV
# Pay attention! If you're using Windows, yours paths might look like:
# r'yolo-coco-data\yolov3.cfg'
# r'yolo-coco-data\yolov3.weights'
# or:
# 'yolo-coco-data\\yolov3.cfg'
# 'yolo-coco-data\\yolov3.weights'
# network = cv2.dnn.readNetFromDarknet('yolo-coco-data/yolov4.cfg',
#                                      'yolo-coco-data/yolov4.weights')
network = cv2.dnn.readNetFromDarknet('yolo-coco-data/yolov3_testing-Copy1.cfg',
                                     'yolo-coco-data/yolov3_training_last-Copy1.weights')

# Getting list with names of all layers from YOLO v3 network
layers_names_all = network.getLayerNames()

# # Check point
# print()
# print(layers_names_all)

# Getting only output layers' names that we need from YOLO v3 algorithm
# with function that returns indexes of layers with unconnected outputs
layers_names_output = \
    [layers_names_all[i[0] - 1] for i in network.getUnconnectedOutLayers()]

# # Check point
# print()
# print(layers_names_output)  # ['yolo_82', 'yolo_94', 'yolo_106']

# Setting minimum probability to eliminate weak predictions
probability_minimum = 0.2

# Setting threshold for filtering weak bounding boxes
# with non-maximum suppression
threshold = 0.1

# Generating colours for representing every detected object
# with function randint(low, high=None, size=None, dtype='l')
colours = np.random.randint(0, 255, size=(len(labels), 3), dtype='uint8')

# # Check point
# print()
# print(type(colours))  # <class 'numpy.ndarray'>
# print(colours.shape)  # (80, 3)
# print(colours[0])  # [172  10 127]

"""
End of:
Loading YOLO v3 network
"""


"""
Start of:
Reading frames in the loop
"""

# Defining variable for counting frames
# At the end we will show total amount of processed frames
f = 0

# Defining variable for counting total time
# At the end we will show time spent for processing all frames
t = 0

# Defining loop for catching frames
while True:
    # Capturing frame-by-frame
    ret, frame = video.read()

    # If the frame was not retrieved
    # e.g.: at the end of the video,
    # then we break the loop
    if not ret:
        break

    # Getting spatial dimensions of the frame
    # we do it only once from the very beginning
    # all other frames have the same dimension
    if w is None or h is None:
        # Slicing from tuple only first two elements
        h, w = frame.shape[:2]

    """
    Start of:
    Getting blob from current frame
    """

    # Getting blob from current frame
    # The 'cv2.dnn.blobFromImage' function returns 4-dimensional blob from current
    # frame after mean subtraction, normalizing, and RB channels swapping
    # Resulted shape has number of frames, number of channels, width and height
    # E.G.:
    # blob = cv2.dnn.blobFromImage(image, scalefactor=1.0, size, mean, swapRB=True)
    blob = cv2.dnn.blobFromImage(frame, 1 / 255.0, (416, 416),
                                 swapRB=True, crop=False)

    """
    End of:
    Getting blob from current frame
    """

    """
    Start of:
    Implementing Forward pass
    """

    # Implementing forward pass with our blob and only through output layers
    # Calculating at the same time, needed time for forward pass
    network.setInput(blob)  # setting blob as input to the network
    start = time.time()
    output_from_network = network.forward(layers_names_output)
    end = time.time()

    # Increasing counters for frames and total time
    f += 1
    t += end - start

    # Showing spent time for single current frame
    print('Frame number {0} took {1:.5f} seconds'.format(f, end - start))

    """
    End of:
    Implementing Forward pass
    """

    """
    Start of:
    Getting bounding boxes
    """

    # Preparing lists for detected bounding boxes,
    # obtained confidences and class's number
    bounding_boxes = []
    confidences = []
    class_numbers = []

    # Going through all output layers after feed forward pass
    for result in output_from_network:
        # Going through all detections from current output layer
        for detected_objects in result:
            # Getting 80 classes' probabilities for current detected object
            scores = detected_objects[5:]
            # Getting index of the class with the maximum value of probability
            class_current = np.argmax(scores)
            # Getting value of probability for defined class
            confidence_current = scores[class_current]

            # # Check point
            # # Every 'detected_objects' numpy array has first 4 numbers with
            # # bounding box coordinates and rest 80 with probabilities
            #  # for every class
            # print(detected_objects.shape)  # (85,)

            # Eliminating weak predictions with minimum probability
            if confidence_current > probability_minimum:
                # Scaling bounding box coordinates to the initial frame size
                # YOLO data format keeps coordinates for center of bounding box
                # and its current width and height
                # That is why we can just multiply them elementwise
                # to the width and height
                # of the original frame and in this way get coordinates for center
                # of bounding box, its width and height for original frame
                box_current = detected_objects[0:4] * np.array([w, h, w, h])

                # Now, from YOLO data format, we can get top left corner coordinates
                # that are x_min and y_min
                x_center, y_center, box_width, box_height = box_current
                x_min = int(x_center - (box_width / 2))
                y_min = int(y_center - (box_height / 2))

                # Adding results into prepared lists
                bounding_boxes.append([x_min, y_min,
                                       int(box_width), int(box_height)])
                confidences.append(float(confidence_current))
                class_numbers.append(class_current)

    """
    End of:
    Getting bounding boxes
    """

    """
    Start of:
    Non-maximum suppression
    """

    # Implementing non-maximum suppression of given bounding boxes
    # With this technique we exclude some of bounding boxes if their
    # corresponding confidences are low or there is another
    # bounding box for this region with higher confidence

    # It is needed to make sure that data type of the boxes is 'int'
    # and data type of the confidences is 'float'
    # https://github.com/opencv/opencv/issues/12789
    results = cv2.dnn.NMSBoxes(bounding_boxes, confidences,
                               probability_minimum, threshold)

    """
    End of:
    Non-maximum suppression
    """

    """
    Start of:
    Drawing bounding boxes and labels
    """

    # Checking if there is at least one detected object
    # after non-maximum suppression
    if len(results) > 0:
        # Going through indexes of results
        for i in results.flatten():
            # Getting current bounding box coordinates,
            # its width and height
            x_min, y_min = bounding_boxes[i][0], bounding_boxes[i][1]
            box_width, box_height = bounding_boxes[i][2], bounding_boxes[i][3]

            # Preparing colour for current bounding box
            # and converting from numpy array to list
            colour_box_current = colours[class_numbers[i]].tolist()

            # # # Check point
            # print(type(colour_box_current))  # <class 'list'>
            # print(colour_box_current)  # [172 , 10, 127]

            # Drawing bounding box on the original current frame
            cv2.rectangle(frame, (x_min, y_min),
                          (x_min + box_width, y_min + box_height),
                          colour_box_current, 2)

            # Preparing text with label and confidence for current bounding box
            text_box_current = '{}: {:.4f}'.format(labels[int(class_numbers[i])],
                                                   confidences[i])

            # Putting text with label and confidence on the original image
            cv2.putText(frame, text_box_current, (x_min, y_min - 5),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.5, colour_box_current, 2)

    """
    End of:
    Drawing bounding boxes and labels
    """

    """
    Start of:
    Writing processed frame into the file
    """

    # Initializing writer
    # we do it only once from the very beginning
    # when we get spatial dimensions of the frames
    if writer is None:
        # Constructing code of the codec
        # to be used in the function VideoWriter
        fourcc = cv2.VideoWriter_fourcc(*'mp4v')

        # Writing current processed frame into the video file
        # Pay attention! If you're using Windows, yours path might looks like:
        # r'videos\result-traffic-cars.mp4'
        # or:
        # 'videos\\result-traffic-cars.mp4'
        writer = cv2.VideoWriter('videos/result-fireblack.mp4', fourcc, 30,
                                 (frame.shape[1], frame.shape[0]), True)

    # Write processed current frame to the file
    writer.write(frame)

    """
    End of:
    Writing processed frame into the file
    """

"""
End of:
Reading frames in the loop
"""


# Printing final results
print()
print('Total number of frames', f)
print('Total amount of time {:.5f} seconds'.format(t))
print('FPS:', round((f / t), 1))


# Releasing video reader and writer
video.release()
writer.release()
# Out:
# Frame number 1 took 2.48770 seconds
# Frame number 2 took 2.18797 seconds
# Frame number 3 took 2.07544 seconds
# Frame number 4 took 2.17969 seconds
# Frame number 5 took 2.09502 seconds
# Frame number 6 took 2.03195 seconds
# Frame number 7 took 2.03276 seconds
# Frame number 8 took 2.01907 seconds
# Frame number 9 took 2.01113 seconds
# Frame number 10 took 2.02129 seconds
# Frame number 11 took 2.28801 seconds
# Frame number 12 took 2.22973 seconds
# Frame number 13 took 2.02592 seconds
# Frame number 14 took 2.04827 seconds
# Frame number 15 took 2.04582 seconds
# Frame number 16 took 2.06128 seconds
# Frame number 17 took 2.05796 seconds
# Frame number 18 took 2.09947 seconds
# Frame number 19 took 2.09033 seconds
# Frame number 20 took 2.08478 seconds
# Frame number 21 took 2.12648 seconds
# Frame number 22 took 2.03935 seconds
# Frame number 23 took 2.04007 seconds
# Frame number 24 took 2.00043 seconds
# Frame number 25 took 2.02134 seconds
# Frame number 26 took 2.01710 seconds
# Frame number 27 took 2.12774 seconds
# Frame number 28 took 2.02448 seconds
# Frame number 29 took 2.03760 seconds
# Frame number 30 took 2.05164 seconds
# Frame number 31 took 2.28226 seconds
# Frame number 32 took 2.26453 seconds
# Frame number 33 took 2.24887 seconds
# Frame number 34 took 2.09496 seconds
# Frame number 35 took 2.09495 seconds
# Frame number 36 took 2.01262 seconds
# Frame number 37 took 2.16558 seconds
# Frame number 38 took 2.00932 seconds
# Frame number 39 took 2.15835 seconds
# Frame number 40 took 2.05741 seconds
# Frame number 41 took 2.02129 seconds
# Frame number 42 took 2.05153 seconds
# Frame number 43 took 2.02205 seconds
# Frame number 44 took 2.01219 seconds
# Frame number 45 took 2.01174 seconds
# Frame number 46 took 2.00452 seconds
# Frame number 47 took 1.98792 seconds
# Frame number 48 took 2.02256 seconds
# Frame number 49 took 2.08126 seconds
# Frame number 50 took 2.08155 seconds
# Frame number 51 took 2.05742 seconds
# Frame number 52 took 2.40546 seconds
# Frame number 53 took 2.18676 seconds
# Frame number 54 took 2.56179 seconds
# Frame number 55 took 2.49460 seconds
# Frame number 56 took 2.52530 seconds
# Frame number 57 took 2.52101 seconds
# Frame number 58 took 2.45857 seconds
# Frame number 59 took 2.52757 seconds
# Frame number 60 took 2.59335 seconds
# Frame number 61 took 2.45637 seconds
# Frame number 62 took 2.18207 seconds
# Frame number 63 took 2.22061 seconds
# Frame number 64 took 2.17060 seconds
# Frame number 65 took 2.23823 seconds
# Frame number 66 took 2.07014 seconds
# Frame number 67 took 2.23500 seconds
# Frame number 68 took 2.19419 seconds
# Frame number 69 took 2.15823 seconds
# Frame number 70 took 2.04093 seconds
# Frame number 71 took 2.17421 seconds
# Frame number 72 took 2.20988 seconds
# Frame number 73 took 2.40476 seconds
# Frame number 74 took 2.40493 seconds
# Frame number 75 took 2.12653 seconds
# Frame number 76 took 2.09958 seconds
# Frame number 77 took 2.05089 seconds
# Frame number 78 took 2.28635 seconds
# Frame number 79 took 2.22056 seconds
# Frame number 80 took 2.03135 seconds
# Frame number 81 took 2.02054 seconds
# Frame number 82 took 2.00885 seconds
# Frame number 83 took 1.99814 seconds
# Frame number 84 took 2.01749 seconds
# Frame number 85 took 2.04244 seconds
# Frame number 86 took 2.01547 seconds
# Frame number 87 took 1.99792 seconds
# Frame number 88 took 1.98860 seconds
# Frame number 89 took 2.03907 seconds
# Frame number 90 took 2.01269 seconds
# Frame number 91 took 2.11146 seconds
# Frame number 92 took 2.05315 seconds
# Frame number 93 took 2.02177 seconds
# Frame number 94 took 2.00466 seconds
# Frame number 95 took 2.01989 seconds
# Frame number 96 took 2.01141 seconds
# Frame number 97 took 1.99962 seconds
# Frame number 98 took 2.02003 seconds
# Frame number 99 took 2.00639 seconds
# Frame number 100 took 2.03649 seconds
# Frame number 101 took 2.00174 seconds
# Frame number 102 took 2.00525 seconds
# Frame number 103 took 2.00913 seconds
# Frame number 104 took 2.13438 seconds
# Frame number 105 took 2.09491 seconds
# Frame number 106 took 2.04225 seconds
# Frame number 107 took 2.03371 seconds
# Frame number 108 took 2.02144 seconds
# Frame number 109 took 2.13937 seconds
# Frame number 110 took 2.02192 seconds
# Frame number 111 took 2.11056 seconds
# Frame number 112 took 2.05814 seconds
# Frame number 113 took 2.27909 seconds
# Frame number 114 took 2.22122 seconds
# Frame number 115 took 2.09829 seconds
# Frame number 116 took 2.01517 seconds
# Frame number 117 took 2.02206 seconds
# Frame number 118 took 1.99241 seconds
# Frame number 119 took 2.01372 seconds
# Frame number 120 took 2.01479 seconds
# Frame number 121 took 2.01829 seconds
# Frame number 122 took 1.99515 seconds
# Frame number 123 took 2.01812 seconds
# Frame number 124 took 2.01592 seconds
# Frame number 125 took 1.99686 seconds
# Frame number 126 took 1.99843 seconds
# Frame number 127 took 1.98650 seconds
# Frame number 128 took 2.03071 seconds
# Frame number 129 took 2.01674 seconds
# Frame number 130 took 2.01065 seconds
# Frame number 131 took 2.00006 seconds
# Frame number 132 took 2.00360 seconds
# Frame number 133 took 2.03570 seconds
# Frame number 134 took 2.12670 seconds
# Frame number 135 took 2.08491 seconds
# Frame number 136 took 2.16121 seconds
# Frame number 137 took 2.07924 seconds
# Frame number 138 took 2.01400 seconds
# Frame number 139 took 1.98774 seconds
# Frame number 140 took 2.00765 seconds
# Frame number 141 took 1.99523 seconds
# Frame number 142 took 2.02188 seconds
# Frame number 143 took 2.02370 seconds
# Frame number 144 took 2.05546 seconds
# Frame number 145 took 2.00386 seconds
# Frame number 146 took 1.98980 seconds
# Frame number 147 took 2.01027 seconds
# Frame number 148 took 1.99787 seconds
# Frame number 149 took 2.01900 seconds
# Frame number 150 took 2.01079 seconds
# Frame number 151 took 1.99940 seconds
# Frame number 152 took 2.01900 seconds
# Frame number 153 took 2.01069 seconds
# Frame number 154 took 2.01979 seconds
# Frame number 155 took 2.03727 seconds
# Frame number 156 took 2.08132 seconds
# Frame number 157 took 2.03602 seconds
# Frame number 158 took 2.02389 seconds
# Frame number 159 took 2.01011 seconds
# Frame number 160 took 2.01953 seconds
# Frame number 161 took 2.10673 seconds
# Frame number 162 took 2.01797 seconds
# Frame number 163 took 2.02198 seconds
# Frame number 164 took 2.01290 seconds
# Frame number 165 took 2.01675 seconds
# Frame number 166 took 2.01588 seconds
# Frame number 167 took 2.00502 seconds
# Frame number 168 took 2.03035 seconds
# Frame number 169 took 2.00214 seconds
# Frame number 170 took 2.03105 seconds
# Frame number 171 took 1.99549 seconds
# Frame number 172 took 2.00501 seconds
# Frame number 173 took 2.01232 seconds
# Frame number 174 took 2.03850 seconds
# Frame number 175 took 2.02066 seconds
# Frame number 176 took 2.01382 seconds
# Frame number 177 took 2.01404 seconds
# Frame number 178 took 2.00113 seconds
# Frame number 179 took 2.01884 seconds
# Frame number 180 took 2.03853 seconds
# Frame number 181 took 2.01959 seconds
# Frame number 182 took 2.04890 seconds
# Frame number 183 took 2.84574 seconds
# Frame number 184 took 2.16126 seconds
# Frame number 185 took 2.84675 seconds
# Frame number 186 took 2.95278 seconds
# Frame number 187 took 2.19456 seconds
# Frame number 188 took 2.10675 seconds
# Frame number 189 took 2.03258 seconds
# Frame number 190 took 2.63124 seconds
# Frame number 191 took 2.60472 seconds
# Frame number 192 took 3.38309 seconds
# Frame number 193 took 3.33771 seconds
# Frame number 194 took 2.72133 seconds
# Frame number 195 took 2.64426 seconds
# Frame number 196 took 2.61963 seconds
# Frame number 197 took 2.61630 seconds
# Frame number 198 took 2.66584 seconds
# Frame number 199 took 2.57906 seconds
# Frame number 200 took 2.65159 seconds
# Frame number 201 took 2.32550 seconds
# Frame number 202 took 2.85215 seconds
# Frame number 203 took 3.01620 seconds
# Frame number 204 took 2.90426 seconds
# Frame number 205 took 3.02244 seconds
# Frame number 206 took 2.91246 seconds
# Frame number 207 took 2.78512 seconds
# Frame number 208 took 2.99669 seconds
# Frame number 209 took 2.44943 seconds
# Frame number 210 took 2.38369 seconds
# Frame number 211 took 2.53548 seconds
# Frame number 212 took 2.63063 seconds
# Frame number 213 took 2.47333 seconds
# Frame number 214 took 2.64290 seconds
# Frame number 215 took 2.39365 seconds
# Frame number 216 took 2.46874 seconds
# Frame number 217 took 2.60360 seconds
# Frame number 218 took 2.60260 seconds
# Frame number 219 took 2.41465 seconds
# Frame number 220 took 2.41023 seconds
# Frame number 221 took 2.53109 seconds
# Frame number 222 took 3.17183 seconds
# Frame number 223 took 2.84630 seconds
# Frame number 224 took 2.17546 seconds
# Frame number 225 took 2.77024 seconds
# Frame number 226 took 2.42789 seconds
# Frame number 227 took 2.29684 seconds
# Frame number 228 took 2.25678 seconds
# Frame number 229 took 2.51527 seconds
# Frame number 230 took 2.22827 seconds
# Frame number 231 took 2.24171 seconds
# Frame number 232 took 2.25994 seconds
# Frame number 233 took 2.49272 seconds
# Frame number 234 took 2.72234 seconds
# Frame number 235 took 2.39917 seconds
# Frame number 236 took 2.21999 seconds
# Frame number 237 took 2.47187 seconds
# Frame number 238 took 2.37021 seconds
# Frame number 239 took 2.23101 seconds
# Frame number 240 took 2.21363 seconds
# Frame number 241 took 2.12244 seconds
# Frame number 242 took 2.34323 seconds
# Frame number 243 took 2.20471 seconds
# Frame number 244 took 2.13369 seconds
# Frame number 245 took 2.42207 seconds
# Frame number 246 took 2.17006 seconds
# Frame number 247 took 2.31328 seconds
# Frame number 248 took 2.33272 seconds
# Frame number 249 took 2.12932 seconds
# Frame number 250 took 2.20198 seconds
# Frame number 251 took 2.60356 seconds
# Frame number 252 took 2.23179 seconds
# Frame number 253 took 2.32304 seconds
# Frame number 254 took 2.29013 seconds
# Frame number 255 took 2.21807 seconds
# Frame number 256 took 2.43815 seconds
# Frame number 257 took 2.38083 seconds
# Frame number 258 took 2.24617 seconds
# Frame number 259 took 2.17299 seconds
# Frame number 260 took 2.26719 seconds
# Frame number 261 took 2.37686 seconds
# Frame number 262 took 2.27078 seconds
# Frame number 263 took 2.24612 seconds
# Frame number 264 took 2.26923 seconds
# Frame number 265 took 2.10183 seconds
# Frame number 266 took 2.07494 seconds
# Frame number 267 took 2.22062 seconds
# Frame number 268 took 2.36688 seconds
# Frame number 269 took 2.32395 seconds
# Frame number 270 took 2.28452 seconds
# Frame number 271 took 2.23684 seconds
# Frame number 272 took 2.20482 seconds
# Frame number 273 took 2.25668 seconds
# Frame number 274 took 2.23196 seconds
# Frame number 275 took 2.41142 seconds
# Frame number 276 took 2.57696 seconds
# Frame number 277 took 2.19866 seconds
# Frame number 278 took 2.20493 seconds
# Frame number 279 took 2.34714 seconds
# Frame number 280 took 2.73291 seconds
# Frame number 281 took 2.15804 seconds
# Frame number 282 took 2.37922 seconds
# Frame number 283 took 2.26338 seconds
# Frame number 284 took 2.27531 seconds
# Frame number 285 took 2.29205 seconds
# Frame number 286 took 2.33980 seconds
# Frame number 287 took 2.51447 seconds
# Frame number 288 took 2.10931 seconds
# Frame number 289 took 2.33214 seconds
# Frame number 290 took 2.59523 seconds
# Frame number 291 took 2.23745 seconds
# Frame number 292 took 2.44264 seconds
# Frame number 293 took 2.29914 seconds
# Frame number 294 took 2.66154 seconds
# Frame number 295 took 2.35292 seconds
# Frame number 296 took 2.29728 seconds
# Frame number 297 took 2.17399 seconds
# Frame number 298 took 2.04681 seconds
# Frame number 299 took 2.10710 seconds
# Frame number 300 took 2.08424 seconds
# Frame number 301 took 2.44428 seconds
# Frame number 302 took 2.26461 seconds
# Frame number 303 took 2.35543 seconds
# Frame number 304 took 2.61977 seconds
# Frame number 305 took 2.23863 seconds
# Frame number 306 took 2.16460 seconds
# Frame number 307 took 2.26640 seconds
# Frame number 308 took 2.49922 seconds
# Frame number 309 took 2.77733 seconds
# Frame number 310 took 2.33166 seconds
# Frame number 311 took 2.30711 seconds
# Frame number 312 took 2.27364 seconds
# Frame number 313 took 2.44117 seconds
# Frame number 314 took 2.41898 seconds
# Frame number 315 took 2.50089 seconds
# Frame number 316 took 2.37828 seconds
# Frame number 317 took 2.85814 seconds
# Frame number 318 took 2.54008 seconds
# Frame number 319 took 2.70464 seconds
# Frame number 320 took 2.84598 seconds
# Frame number 321 took 2.50276 seconds
# Frame number 322 took 2.12447 seconds
# Frame number 323 took 2.13110 seconds
# Frame number 324 took 2.32810 seconds
# Frame number 325 took 2.26564 seconds
# Frame number 326 took 2.12014 seconds
# Frame number 327 took 2.06747 seconds
# Frame number 328 took 2.29252 seconds
# Frame number 329 took 2.75845 seconds
# Frame number 330 took 2.45436 seconds
# Frame number 331 took 2.12546 seconds
# Frame number 332 took 2.03346 seconds
# Frame number 333 took 2.12582 seconds
# Frame number 334 took 2.35910 seconds
# Frame number 335 took 2.46508 seconds
# Frame number 336 took 2.38108 seconds
# Frame number 337 took 2.35966 seconds
# Frame number 338 took 2.35864 seconds
# Frame number 339 took 2.25214 seconds
# Frame number 340 took 2.08328 seconds
# Frame number 341 took 2.18226 seconds
# Frame number 342 took 2.02445 seconds
# Frame number 343 took 2.07924 seconds
# Frame number 344 took 2.17972 seconds
# Frame number 345 took 2.44578 seconds
# Frame number 346 took 2.15478 seconds
# Frame number 347 took 2.08189 seconds
# Frame number 348 took 2.12732 seconds
# Frame number 349 took 3.21400 seconds
# Frame number 350 took 2.93516 seconds
# Frame number 351 took 2.82814 seconds
# Frame number 352 took 2.64580 seconds
# Frame number 353 took 2.63621 seconds
# Frame number 354 took 2.54335 seconds
# Frame number 355 took 2.60737 seconds
# Frame number 356 took 2.59814 seconds
# Frame number 357 took 2.71593 seconds
# Frame number 358 took 2.42423 seconds
# Frame number 359 took 2.40309 seconds
# Frame number 360 took 2.54625 seconds
# Frame number 361 took 2.46504 seconds
# Frame number 362 took 2.49905 seconds
# Frame number 363 took 2.46800 seconds
# Frame number 364 took 2.50624 seconds
# Frame number 365 took 2.51651 seconds
# Frame number 366 took 2.39990 seconds
# Frame number 367 took 2.72239 seconds
# Frame number 368 took 2.31774 seconds
# Frame number 369 took 2.11616 seconds
# Frame number 370 took 2.30869 seconds
# Frame number 371 took 2.09539 seconds
# Frame number 372 took 2.10672 seconds
# Frame number 373 took 2.08222 seconds
# Frame number 374 took 2.05737 seconds
# Frame number 375 took 2.01958 seconds
# Frame number 376 took 2.08842 seconds
# Frame number 377 took 2.16538 seconds
# Frame number 378 took 2.62431 seconds
# Frame number 379 took 2.04859 seconds
# Frame number 380 took 2.98631 seconds
# Frame number 381 took 2.36373 seconds
# Frame number 382 took 2.20112 seconds
# Frame number 383 took 2.00461 seconds
# Frame number 384 took 1.98830 seconds
# Frame number 385 took 2.01712 seconds
# Frame number 386 took 1.99477 seconds
# Frame number 387 took 2.03255 seconds
# Frame number 388 took 2.01417 seconds
# Frame number 389 took 2.02855 seconds
# Frame number 390 took 2.02884 seconds
# Frame number 391 took 1.98535 seconds
# Frame number 392 took 2.00219 seconds
# Frame number 393 took 1.98654 seconds
# Frame number 394 took 2.02771 seconds
# Frame number 395 took 2.02320 seconds
# Frame number 396 took 2.03668 seconds
# Frame number 397 took 2.21221 seconds
# Frame number 398 took 2.18426 seconds
# Frame number 399 took 2.39101 seconds
# Frame number 400 took 2.21106 seconds
# Frame number 401 took 2.83230 seconds
# Frame number 402 took 2.29011 seconds
# Frame number 403 took 2.73794 seconds
# Frame number 404 took 2.24683 seconds
